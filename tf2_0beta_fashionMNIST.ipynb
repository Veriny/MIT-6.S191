# %% [markdown]
# <a href="https://colab.research.google.com/github/Veriny/MIT-6.S191/blob/master/tf2_0beta_fashionMNIST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Use Tensorflow 2.0 Beta
# !pip install -q tensorflow==2.0.0-beta1

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras

# Helper libraries
import numpy as np
import matplotlib.pyplot as plot
# %matplotlib inline
print(tf.__version__)
# Out:
# 2.0.0-beta1

# %%
dataset = keras.datasets.fashion_mnist

# %%
(train_images, train_labels) , (test_images, test_labels) = dataset.load_data()
train_images = train_images / 255.0
test_images = test_images / 255.0

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']#Possible outcomes of the image.

# %%
plot.figure()

# %%
plot.imshow(train_images[56
                     ])

# %%
plot.plot(train_images[56])

# %%
for i in range(25):
    plot.subplot(5,5,i+1)
    plot.xticks([])
    plot.yticks([])
    plot.grid(False)
    plot.imshow(train_images[i], cmap=plot.cm.binary)
    plot.xlabel(class_names[train_labels[i]])
plot.show()

# %%
#Making the model
model = keras.Sequential()

# %%
model.add(keras.layers.Flatten(input_shape=(28,28)))
model.add(keras.layers.Dense(128, activation = 'relu'))
model.add(keras.layers.Dense(10, activation = 'softmax'))

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(train_images, train_labels, epochs=50)
# Out:
# Train on 60000 samples
# Epoch 1/50
# 60000/60000 [==============================] - 5s 76us/sample - loss: 0.2309 - accuracy: 0.9144
# Epoch 2/50
# 60000/60000 [==============================] - 5s 75us/sample - loss: 0.2259 - accuracy: 0.9158
# Epoch 3/50
# 60000/60000 [==============================] - 4s 75us/sample - loss: 0.2188 - accuracy: 0.9183
# Epoch 4/50
# 60000/60000 [==============================] - 4s 74us/sample - loss: 0.2123 - accuracy: 0.9201
# Epoch 5/50
# 60000/60000 [==============================] - 4s 74us/sample - loss: 0.2052 - accuracy: 0.9234
# Epoch 6/50
# 60000/60000 [==============================] - 4s 72us/sample - loss: 0.2006 - accuracy: 0.9249
# Epoch 7/50
# 60000/60000 [==============================] - 4s 73us/sample - loss: 0.1941 - accuracy: 0.9270
# Epoch 8/50
# 60000/60000 [==============================] - 4s 73us/sample - loss: 0.1893 - accuracy: 0.9294
# Epoch 9/50
# ...

# %%
#Let's see how garbage the model is
isthisloss, accuracy = model.evaluate(test_images, test_labels)
# Out:
# 10000/10000 [==============================] - 0s 38us/sample - loss: 0.5310 - accuracy: 0.8864

# %%
print(isthisloss)
# Out:
# 0.3372208231210709

# %%
print(test_acc)
# Out:
# 0.1

# %%
preds = model.predict(test_images)

for i in range(500):
  print(preds[i])
# Out:
# [8.8373888e-08 1.8141245e-10 1.0170811e-09 1.3018382e-11 8.2934515e-10
#  4.7920083e-05 1.8833111e-07 1.9559609e-03 5.3592373e-08 9.9799585e-01]
# [2.5411288e-04 8.4210978e-11 9.9745780e-01 6.6058037e-10 3.5502130e-04
#  3.1258410e-10 1.9331088e-03 2.2239610e-09 7.7006936e-11 2.8577252e-13]
# [5.6801071e-09 1.0000000e+00 6.5107837e-13 7.2075890e-10 1.5312526e-12
#  4.9707187e-24 5.8574909e-11 6.9323610e-20 1.6645678e-11 9.2756494e-18]
# [1.6429316e-07 9.9999905e-01 4.3559137e-10 7.6415472e-07 2.0356625e-09
#  5.7531368e-19 1.3202855e-08 8.9387625e-17 2.4258222e-11 4.3518648e-12]
# [1.1171130e-01 9.3378205e-08 2.2875767e-03 9.0045232e-04 6.2090898e-04
#  2.2187340e-05 8.8444269e-01 2.7429158e-07 1.4517630e-05 6.9017254e-08]
# [3.1595784e-05 9.9996567e-01 5.0015507e-09 3.1129468e-07 7.2132145e-10
#  1.1759653e-17 2.3230943e-06 4.4372361e-16 6.8375189e-10 1.0230205e-13]
# [1.9374977e-05 4.9531158e-05 8.1644277e-04 1.3671109e-05 9.8336476e-01
# ...
